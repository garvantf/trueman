# %%
pip install pandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 10.3/10.3 MB 6.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 499.4/499.4 kB 6.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.8/14.8 MB 6.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install psycopg2
# Out:
# ...
#      ---------------------------------------- 1.2/1.2 MB 4.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import psycopg2 as ps

# %%
kon = ps.connect(dbname="newDatabase",user="postgres",password="123",host="localhost",port="5432")
que = """select * from public.iris"""
df = pd.read_sql_query(que,kon)
df
# Out:
# C:\Users\Garvan\AppData\Local\Temp\ipykernel_9356\1713563959.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(que,kon)
#       id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# ...
